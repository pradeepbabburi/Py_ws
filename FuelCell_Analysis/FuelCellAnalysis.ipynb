# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DST_240-408h.csv', delimiter=',')
time = data['101(Seconds)']
cell_1_V = data['101(VDC)']
cell_1_C = data['201(C)']

# %%
n = 100000
plt.figure()
plt.plot(time[0:n], cell_1_C[0:n])
plt.xlabel('Time (s)')
plt.ylabel('Cell 1 current (A)')
plt.show()
